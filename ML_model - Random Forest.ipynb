# %% [markdown]
# # Supervised Machine Learning - Random Forest Classifier

# %% [markdown]
# ### Dependencies:

# %%
import numpy as np
import pandas as pd

from pathlib import Path
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.metrics import classification_report_imbalanced
from imblearn.ensemble import EasyEnsembleClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression


import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy import extract

# %%
columns = ["obj_ID",'alpha','delta', 'u', 'g', 'r', 'i', 'z', 'run_ID',
       'rerun_ID', 'cam_col', 'field_ID', 'spec_obj_ID', 'redshift',
       'plate', 'MJD', 'fiber_ID']
target = ["class"]

# %%
# # Create engine
# engine = create_engine("sqlite:///

# %%
# # reflect an existing database into a new model
# Base = automap_base()
# # reflect the tables
# Base.prepare(engine, reflect=True)
# # Save references to each table
# Measurement = Base.classes.measurement
# Station = Base.classes.station

# %%
# # Create our session (link) from Python to the DB
# session = Session(engine)

# %%
# Load the data
file_path = Path('Resources/star.csv', index=False)
data_df = pd.read_csv(file_path)
# df = df.loc[:, columns].copy()
data_df
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 0      1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1      1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2      1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3      1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4      1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
# ...             ...         ...        ...       ...       ...       ...
# 99995  1.237679e+18   39.620709  -2.594074  22.16759  22.97586  21.90404
# 99996  1.237679e+18   29.493819  19.798874  22.69118  22.38628  20.45003
# 99997  1.237668e+18  224.587407  15.700707  21.16916  19.26997  18.20428
# 99998  1.237661e+18  212.268621  46.660365  25.35039  21.63757  19.91386
# 99999  1.237661e+18  196.896053  49.464643  22.62171  21.79745  20.60115
#
#               i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 0      19.16573  18.79371    3606       301        2        79  6.543777e+18
# 1      21.16812  21.61427    4518       301        5       119  1.176014e+19
# 2      19.34857  18.94827    3606       301        2       120  5.152200e+18
# 3      20.50454  19.25010    4192       301        3       214  1.030107e+19
# 4      15.97711  15.54461    8102       301        3       137  6.891865e+18
# ...         ...       ...     ...       ...      ...       ...           ...
# 99995  21.30548  20.73569    7778       301        2       581  1.055431e+19
# 99996  19.75759  19.41526    7917       301        1       289  8.586351e+18
# 99997  17.69034  17.35221    5314       301        4       308  3.112008e+18
# 99998  19.07254  18.62482    3650       301        4       131  7.601080e+18
# 99999  20.00959  19.28075    3650       301        4        60  8.343152e+18
#
#         class  redshift  plate    MJD  fiber_ID
# 0      GALAXY  0.634794   5812  56354       171
# 1      GALAXY  0.779136  10445  58158       427
# 2      GALAXY  0.644195   4576  55592       299
# 3      GALAXY  0.932346   9149  58039       775
# 4      GALAXY  0.116123   6121  56187       842
# ...       ...       ...    ...    ...       ...
# 99995  GALAXY  0.000000   9374  57749       438
# 99996  GALAXY  0.404895   7626  56934       866
# 99997  GALAXY  0.143366   2764  54535        74
# 99998  GALAXY  0.455040   6751  56368       470
# 99999  GALAXY  0.542944   7410  57104       851
#
# [100000 rows x 18 columns]

# %%
data_df.set_index(['spec_obj_ID'], inplace = True)

# %%
data_df
# Out:
#                     obj_ID       alpha      delta         u         g  \
# spec_obj_ID
# 6.543777e+18  1.237661e+18  135.689107  32.494632  23.87882  22.27530
# 1.176014e+19  1.237665e+18  144.826101  31.274185  24.77759  22.83188
# 5.152200e+18  1.237661e+18  142.188790  35.582444  25.26307  22.66389
# 1.030107e+19  1.237663e+18  338.741038  -0.402828  22.13682  23.77656
# 6.891865e+18  1.237680e+18  345.282593  21.183866  19.43718  17.58028
# ...                    ...         ...        ...       ...       ...
# 1.055431e+19  1.237679e+18   39.620709  -2.594074  22.16759  22.97586
# 8.586351e+18  1.237679e+18   29.493819  19.798874  22.69118  22.38628
# 3.112008e+18  1.237668e+18  224.587407  15.700707  21.16916  19.26997
# 7.601080e+18  1.237661e+18  212.268621  46.660365  25.35039  21.63757
# 8.343152e+18  1.237661e+18  196.896053  49.464643  22.62171  21.79745
#
#                      r         i         z  run_ID  rerun_ID  cam_col  \
# spec_obj_ID
# 6.543777e+18  20.39501  19.16573  18.79371    3606       301        2
# 1.176014e+19  22.58444  21.16812  21.61427    4518       301        5
# 5.152200e+18  20.60976  19.34857  18.94827    3606       301        2
# 1.030107e+19  21.61162  20.50454  19.25010    4192       301        3
# 6.891865e+18  16.49747  15.97711  15.54461    8102       301        3
# ...                ...       ...       ...     ...       ...      ...
# 1.055431e+19  21.90404  21.30548  20.73569    7778       301        2
# 8.586351e+18  20.45003  19.75759  19.41526    7917       301        1
# 3.112008e+18  18.20428  17.69034  17.35221    5314       301        4
# 7.601080e+18  19.91386  19.07254  18.62482    3650       301        4
# 8.343152e+18  20.60115  20.00959  19.28075    3650       301        4
#
#               field_ID   class  redshift  plate    MJD  fiber_ID
# spec_obj_ID
# 6.543777e+18        79  GALAXY  0.634794   5812  56354       171
# 1.176014e+19       119  GALAXY  0.779136  10445  58158       427
# 5.152200e+18       120  GALAXY  0.644195   4576  55592       299
# 1.030107e+19       214  GALAXY  0.932346   9149  58039       775
# 6.891865e+18       137  GALAXY  0.116123   6121  56187       842
# ...                ...     ...       ...    ...    ...       ...
# 1.055431e+19       581  GALAXY  0.000000   9374  57749       438
# 8.586351e+18       289  GALAXY  0.404895   7626  56934       866
# 3.112008e+18       308  GALAXY  0.143366   2764  54535        74
# 7.601080e+18       131  GALAXY  0.455040   6751  56368       470
# 8.343152e+18        60  GALAXY  0.542944   7410  57104       851
#
# [100000 rows x 17 columns]

# %%
 new_data_df=data_df.drop(['alpha','delta','run_ID','rerun_ID', 'cam_col', 'field_ID', "obj_ID",'plate', 'MJD', 'fiber_ID'], axis = 1 )

# %%
new_data_df
# Out:
#                      u         g         r         i         z   class  \
# spec_obj_ID
#
#
#               redshift binned_u binned_g binned_r binned_i binned_z
# spec_obj_ID
# 5.973053e+18  0.518788        3        3        2        2        3
# 2.446687e+18  0.032378        3        3        2        2        3
# 7.598769e+18  0.325445        3        3        2        2        3
# 6.770139e+18  0.447621        3        3        2        2        3
# 1.124845e+18  0.055841        3        3        1        1        3
# 4.942814e+18  0.585957        3        3        2        2        3
# 6.074346e+18  2.369097        3        3        2        2        3
# 7.235298e+18  0.633924        3        3        2        2        3
# 1.152717e+19  0.737555        3        3        2        2        3
# 9.339342e+18  0.725942        3        3        2        2        3
# 2.434277e+18  0.180706        3        3        2        1        3
# 2.677476e+18  0.000148        3        3        2        2        3
# 2.272070e+18  1.771213        3        3        2        2        3
# 1.429934e+18  0.119817        3        3        2        1        3
# 8.728023e+18 -0.000203        3        3        2        2        3
# 8.630066e+18  0.402437        3        3        2        2        3
# 8.217031e+18  0.553679        3        3        2        2        3
# 1.775670e+18 -0.000211        3        3        2        2        3
# 1.158105e+19  1.721393        3        3        2        2        3
# 1.210477e+19  0.550010        3        3        2        2        3
# 8.203473e+18  0.000020        3        3        2        2        3
# 2.203491e+18  0.106944        3        3        1        1        3
# 5.980189e+17  0.077254        3        3        1        1        3
# 6.429154e+18  0.495281        3        3        2        2        3
# 9.605240e+18 -0.000776        3        3        2        2        3
# 7.094433e+18 -0.000589        3        3        2        2        3
# 9.934046e+18  0.000250        3        3        2        2        3
# 7.327372e+18  0.544793        3        3        2        2        3
# 5.664181e+17 -0.000008        3        3        1        1        3
# 9.462077e+18  0.796334        3        3        2        2        3

# %%
new_data_df.iloc[new_data_df.values==np.inf]
new_data_df =new_data_df[~new_data_df.isin([np.nan, np.inf, -np.inf]).any(1)]

# %% [markdown]
# ### Test and Train Data

# %%
# Create our features
X = new_data_df.drop('class', axis=1)

# Create our target
y = new_data_df['class']

X
# Out:
#                      u         g         r         i         z  redshift  \
# spec_obj_ID
# 6.543777e+18  23.87882  22.27530  20.39501  19.16573  18.79371  0.634794
# 1.176014e+19  24.77759  22.83188  22.58444  21.16812  21.61427  0.779136
# 5.152200e+18  25.26307  22.66389  20.60976  19.34857  18.94827  0.644195
# 1.030107e+19  22.13682  23.77656  21.61162  20.50454  19.25010  0.932346
# 6.891865e+18  19.43718  17.58028  16.49747  15.97711  15.54461  0.116123
# ...                ...       ...       ...       ...       ...       ...
# 1.055431e+19  22.16759  22.97586  21.90404  21.30548  20.73569  0.000000
# 8.586351e+18  22.69118  22.38628  20.45003  19.75759  19.41526  0.404895
# 3.112008e+18  21.16916  19.26997  18.20428  17.69034  17.35221  0.143366
# 7.601080e+18  25.35039  21.63757  19.91386  19.07254  18.62482  0.455040
# 8.343152e+18  22.62171  21.79745  20.60115  20.00959  19.28075  0.542944
#
#              binned_u binned_g binned_r binned_i binned_z
# spec_obj_ID
# 6.543777e+18        3        3        2        2        3
# 1.176014e+19        3        3        2        2        3
# 5.152200e+18        3        3        2        2        3
# 1.030107e+19        3        3        2        2        3
# 6.891865e+18        3        3        2        1        3
# ...               ...      ...      ...      ...      ...
# 1.055431e+19        3        3        2        2        3
# 8.586351e+18        3        3        2        2        3
# 3.112008e+18        3        3        2        2        3
# 7.601080e+18        3        3        2        2        3
# 8.343152e+18        3        3        2        2        3
#
# [100000 rows x 11 columns]

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1,stratify=y)
Counter(y_train)
# Out:
# Counter({'GALAXY': 44584, 'STAR': 16195, 'QSO': 14221})

# %% [markdown]
# ### Random Oversampling

# %%
# Resample the training data with the RandomOverSampler
ros = RandomOverSampler(random_state=1)
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)
Counter(y_resampled)
# Out:
# Counter({'GALAXY': 44584, 'STAR': 44584, 'QSO': 44584})

# %% [markdown]
# ### Random Forest Classifier Algorithm (Galaxies, QSO and Stars) - Oversampling

# %%
# Train the Random Forest Classifier Model using the resampled data
model = RandomForestClassifier(n_estimators=100)
model.fit(X_resampled, y_resampled)
# Out:
# RandomForestClassifier()

# %%
# Calculated the balanced accuracy score
y_pred = model.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.9729720856934846

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test,y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#      GALAXY       0.98      0.98      0.97      0.98      0.98      0.96     14861
#         QSO       0.95      0.94      0.99      0.94      0.96      0.92      4740
#        STAR       1.00      1.00      1.00      1.00      1.00      1.00      5399
#
# avg / total       0.98      0.98      0.98      0.98      0.98      0.96     25000

# %%
# Display the confusion matrix
c= confusion_matrix(y_test,y_pred)
cmros = pd.DataFrame(c, index=["Actual 0", "Actual 1", "Actual 2"], columns=["Predicted 0", "Predicted 1", "Predicted 2"])
cmros
# Out:
#           Predicted 0  Predicted 1  Predicted 2
# Actual 0        14617          220           24
# Actual 1          302         4437            1
# Actual 2            4            0         5395

# %% [markdown]
# ### Random Undersampling

# %%
# Resample the training data with the RandomUnderSampler
rus = RandomUnderSampler(random_state=1)
X_resampled1, y_resampled1 = rus.fit_resample(X_train, y_train)
Counter(y_resampled1)
# Out:
# Counter({'GALAXY': 14221, 'QSO': 14221, 'STAR': 14221})

# %% [markdown]
# ### Random Forest Classifier Algorithm (Galaxies, QSO and Stars) - Undersampling

# %%
# Train the Random Forest Classifier Model using the resampled data
model = RandomForestClassifier(n_estimators=100)
model.fit(X_resampled1, y_resampled1)
# Out:
# RandomForestClassifier()

# %%
# Calculated the balanced accuracy score
y_pred2 = model.predict(X_test)
balanced_accuracy_score(y_test, y_pred2)
# Out:
# 0.9734642233611402

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test,y_pred2))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#      GALAXY       0.98      0.97      0.98      0.98      0.97      0.95     14861
#         QSO       0.92      0.95      0.98      0.93      0.97      0.93      4740
#        STAR       0.99      1.00      1.00      0.99      1.00      1.00      5399
#
# avg / total       0.97      0.97      0.98      0.97      0.98      0.95     25000

# %%
# Display the confusion matrix
c= confusion_matrix(y_test,y_pred2)
cmrus = pd.DataFrame(c, index=["Actual 0", "Actual 1", "Actual 2"], columns=["Predicted 0", "Predicted 1", "Predicted 2"])
cmrus
# Out:
#           Predicted 0  Predicted 1  Predicted 2
# Actual 0        14383          414           64
# Actual 1          223         4516            1
# Actual 2            1            0         5398

# %% [markdown]
# ### SMOTE

# %%
# Resample the training data with the SMOTE
from imblearn.over_sampling import SMOTE
smo=SMOTE(random_state=1,sampling_strategy='auto')
X_resampled2, y_resampled2=smo.fit_resample(X_train, y_train)
Counter(y_resampled2)
# Out:
# Counter({'GALAXY': 44584, 'STAR': 44584, 'QSO': 44584})

# %% [markdown]
# ### Random Forest Classifier Algorithm (Galaxies, QSO and Stars) - SMOTE

# %%
# Train the Random Forest Classifier Model using the resampled data
model = RandomForestClassifier(n_estimators=100)
model.fit(X_resampled2, y_resampled2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/s9/td78276s5k7b8rbn6y3t4p1h0000gn/T/ipykernel_34504/1218515038.py in <module>
#       1 # Train the Random Forest Classifier Model using the resampled data
#       2 model = RandomForestClassifier(n_estimators=100)
# ----> 3 model.fit(X_resampled2, y_resampled2)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     303             )
#     304         X, y = self._validate_data(X, y, multi_output=True,
# --> 305                                    accept_sparse="csc", dtype=DTYPE)
#     306         if sample_weight is not None:
#     307             sample_weight = _check_sample_weight(sample_weight, X)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     876                     ensure_min_samples=ensure_min_samples,
#     877                     ensure_min_features=ensure_min_features,
# --> 878                     estimator=estimator)
#     879     if multi_output:
#     880         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     719         if force_all_finite:
#     720             _assert_all_finite(array,
# --> 721                                allow_nan=force_all_finite == 'allow-nan')
#     722
#     723     if ensure_min_samples > 0:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     104                     msg_err.format
#     105                     (type_err,
# --> 106                      msg_dtype if msg_dtype is not None else X.dtype)
#     107             )
#     108     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
# Calculated the balanced accuracy score
y_pred3 = model.predict(X_test)
balanced_accuracy_score(y_test, y_pred3)

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test,y_pred3))

# %%
# Display the confusion matrix
c= confusion_matrix(y_test,y_pred3)
cms = pd.DataFrame(c, index=["Actual 0", "Actual 1", "Actual 2"], columns=["Predicted 0", "Predicted 1", "Predicted 2"])
cms
