# %%
from config import password
import pandas as pd

# %%
import sqlalchemy as sa

engine = sa.create_engine("postgresql://postgres:" + password + "@localhost:5432/Stellar_Classification")

# %%
# Load the sql extension:

# %reload_ext sql

# %%
# Set up the connection:

# %sql $engine.url

# %%
# Now we use the magic command %sql to make a SQL query to the table “Stellar” inside a database called “Stellar_Constellation”:

sample = %sql SELECT * FROM stellar LIMIT 100

# Turn SQL results into df
sample.DataFrame()
# Out:
#  * postgresql://postgres:***@localhost:5432/Stellar_Classification
# 100 rows affected.
#           obj_id       alpha      delta         u         g         r  \
# 0   1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1   1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2   1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3   1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4   1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
# ..           ...         ...        ...       ...       ...       ...
# 95  1.237666e+18  348.335815  25.685581  23.93912  22.92743  21.78178
# 96  1.237671e+18   42.048515  32.466019  21.80150  18.61152  17.18664
# 97  1.237662e+18  169.417236   7.719850  25.08139  22.03635  21.83119
# 98  1.237662e+18  243.498908   4.309792  21.23949  20.39086  20.35097
# 99  1.237678e+18   44.374089   3.017933  25.76758  22.40062  20.49454
#
# ...
