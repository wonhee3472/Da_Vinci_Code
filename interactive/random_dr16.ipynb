# %%
# Dependencies and Setup
import pandas as pd

# %%
#Read in csv as dataframe
df = pd.read_csv("../Resources/dr16.csv")
df.head()
# Out:
#                  objid          ra        dec         u         g         r  \
# 0  1237666301628060000   47.372545   0.820621  18.69254  17.13867  16.55555
# 1  1237673706652430000  116.303083  42.455980  18.47633  17.30546  17.24116
# 2  1237671126974140000  172.756623  -8.785698  16.47714  15.31072  15.55971
# 3  1237665441518260000  201.224207  28.771290  18.63561  16.88346  16.09825
# 4  1237665441522840000  212.817222  26.625225  18.88325  17.87948  17.47037
#
#           i         z   run  rerun  camcol  field            specobjid  \
# 0  16.34662  16.17639  4849    301       5    771  8168632633242440000
# 1  17.32780  17.37114  6573    301       6    220  9333948945297330000
# 2  15.72207  15.82471  5973    301       1     13  3221211255238850000
# 3  15.70987  15.43491  4649    301       3    121  2254061292459420000
# 4  17.17441  17.05235  4649    301       3    191  2390305906828010000
#
#     class  redshift  plate    mjd  fiberid
# ...

# %%
df.set_index(['specobjid'], inplace = True)

# %%
df.drop(["objid",'ra','dec','u',g,r,i,z,redshift,plate,mjd,fiberid], axis = 1 )

# %%
df_star = df.loc[(df['class'] == 'STAR')]
df_star.sample(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.UInt64Engine._check_type()
#
# KeyError: 'run'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_43188\3158631487.py in <module>
# ...

# %%
df_galaxy= df.loc[(df['class'] == 'GALAXY')]
df_galaxy.sample(10)
# Out:
#                                    objid          ra        dec         u  \
# specobjid
# 828714870378621000   1237656495639430000  333.863474  12.917502  18.57411
# 3096277591544330000  1237668349213020000  222.655075  13.778640  19.15935
# 943514057435015000   1237655125542500000  176.262481   5.030269  19.25610
# 2737090225380550000  1237667731273220000  133.593842  14.846462  17.75543
# 7582043726039770000  1237661386536390000  229.675244  47.551264  17.39692
# 2803648068312920000  1237668294446350000  168.122119  19.819034  17.06687
# 1070737448708890000  1237655107301280000  172.139217  58.562834  14.33296
# 1607862083083330000  1237661138497370000  155.029970  38.699031  18.70358
# 2829476145567660000  1237667736116330000  177.220024  23.016185  18.90788
# 2077359889562230000  1237662697032380000  227.168864  29.187146  18.69764
#
#                             g         r         i         z   run  rerun  \
# specobjid
# ...

# %%
df_quasar = df.loc[(df['class'] == 'QSO')]
df_quasar.sample(10)
# Out:
#                                    objid          ra        dec         u  \
# specobjid
# 392976204510030000   1237671938729900000  253.907472  62.794196  19.52497
# 860237594154265000   1237655108363880000  133.513782  47.196058  18.88461
# 1969324062836550000  1237661070863960000  161.590148  14.773361  19.37134
# 2845257718019680000  1237668336324510000  242.350175  13.695381  17.41482
# 409829798668429000   1237648702994510000  247.395886  -1.094064  17.72142
# 4517227613614530000  1237648703523910000  230.332001  -0.805225  19.18500
# 502294051945474000   1237651272425140000  131.016377  54.400450  19.47578
# 3640171095199420000  1237674649925320000  172.251373  -0.414326  18.84920
# 2387046955353140000  1237665429169570000  210.487312  27.796822  19.28232
# 678950388791011000   1237654609608570000  203.127117  63.467745  19.57756
#
#                             g         r         i         z   run  rerun  \
# specobjid
# ...
